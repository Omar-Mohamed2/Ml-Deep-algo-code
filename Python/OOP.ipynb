# %% [markdown]
# OOP

# %%
from abc import ABC ,abstractclassmethod ,abstractmethod
 
# encapsulation 

class Students:
    
    no_ob=0
    
    def __init__(Self , __name , __id=0 ,__age=0):
       Self.__name=__name
       Self.__id=__id
       Self.__age=__age
       Students.no_ob+=1
    def getattr(self):
     print(f"name:{self.__name}")
     print(f"id=:{self.__id}")
     print(f"age={self.__age}") 


    def set_name(self , name):
       
       self.__name=name 

    def set_id(self,id):
       
       self.__id=id
    
    def set_age(self,age):
       
       self.__age=age 
    def data(self):
       print(f"my name is {self.__name} , my id={self.__id} , my age ={self.__age}")

    # class method "another init"
    @classmethod
    def specific(cls):
       return cls("Mohamed" ,200023,22)
    

    # static method utility or helper method

    #@staticmethod 


    # inherit and poly 

class tec(Students):
     no_tec=0
     def __init__(Self, __name, __id=0, __age=0,__section="unknown"):
        super().__init__(__name, __id, __age)
        Self.__section=__section
        
     def data(self):
       super().data()
       print(f"the sec={self.__section}")


       
Student1=Students("omar") 
print("the data for std1 =: \n") 
Student1.getattr()  
print("\n")

print("the entered data using caps \n")

Student1.set_age(9)
Student1.getattr()
Student1.data() 


print("the data for std2 =: \n") 

std2=Students.specific()
std2.data()

print(f"the number of object created={Students.no_ob}") 
 

tec1=tec("sara")
tec1.data() 

print(f"the number of object created from 2 class={Students.no_ob}")  


print ( isinstance(tec1, tec))
# Out:
# the data for std1 =:
#
# name:omar
# id=:0
# age=0
#
#
# the entered data using caps
#
# name:omar
# id=:0
# age=9
# my name is omar , my id=0 , my age =9
# the data for std2 =:
#
# my name is Mohamed , my id=200023 , my age =22
# the number of object created=2
# my name is sara , my id=0 , my age =0
# the sec=unknown
# the number of object created from 2 class=3
# True
